# %%
import matplotlib.pyplot as plt

plt.scatter([1, 5], [3, 4])
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 7)
plt.ylim(0, 5)

plt.annotate("$(x_1, y_1) = (1, 3)$", (0.5, 3.25))
plt.annotate("$(x_2, y_2) = (4, 4)$", (4.5, 4.25))
# Out:
# Text(4.5, 4.25, '$(x_2, y_2) = (4, 4)$')
